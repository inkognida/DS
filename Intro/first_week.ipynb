# %%
import pandas as pd
import numpy as np
import seaborn as sns #new lib
import matplotlib.pyplot as plt #new lib
# %config InlineBackend.figure_format = 'retina' 
# %matplotlib inline

df = pd.read_csv('/Users/artemshibaev/downloads/StudentsPerformance.csv')

### LESSON 1 
#df.iloc[0:5, 0:3] intege locationr
#df.loc[[0:2], ['gender, race']] index location
#df.head() first (5) strokes
#df.tail() last (5) strokes
#df.index return indexes
#df.columns return columns
#df.describe() return different variables for the dataset 

### LESSON 2
#df.gender == 'female' return true/false for column 'gender' 
#df.loc[df.gender == 'female', ['gender', 'writing score']] get only 'female' sets with columns 'gen' and 'wrt sc'
# mean = df['writing score'].mean()
# df.loc[df['writing score'] > mean]   get columns where 'writing score' > mean for 'wtiring score'
# df.loc[(df['writing score'] > 100) & (df.gender == 'female')] 
#query = (df['writing score'] > mean) & (df.gender == 'female') mean=df['writing score'].mean()multiple condition
# df.loc[df['lunch'] == 'free/reduced'].iloc[0:, 5:].var()
# df.loc[df['lunch'] != 'free/reduced'].iloc[0:, 5:].var() var - дисперссия, describe() - другие показатели 
df = df\
                                .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'}) #renaming of the columns
# sub = 78 #extra param
# df.query("lunch == 'standard' & writing_score > @sub") # for the extra param use @, for str types ''

#columns_score = [i for i in list(df) if 'score' in i] get columns with 'score' inside
#df.filter(like = 'gender', axis = 1) filter df by 'gender' for columns axis = 1 - columns; 0 - strokes

#df.groupby('gender', as_index = False).aggregate({'math_score': 'mean', 'reading_score': 'mean'})
# ^ groupby 'gender' mean for 2 columns

#df.groupby(['gender','race/ethnicity'],as_index=False).aggregate({'math_score': 'mean', 'reading_score': 'mean'})
# ^ groupby 2 columns and mean for 2 columns
# df_2 = df.groupby(['gender','race/ethnicity'])\
#     .aggregate({'math_score': 'mean', 'reading_score': 'mean'})
# df.sort_values(['gender','math_score'], ascending = False).groupby('gender').head()
#df_2.loc[[('female', 'group A'), ('female', 'group B')]] multiple location[tuples with double indexes


#  LESSON 4


# ^ implementaion right here(means graphics)
#df.math_score.hist() histogram
#df.plot.scatter(x='math_score', y='reading_score') plot.scatter with matplotlib
sns.lmplot(x='math_score', y='reading_score', hue = 'gender', fit_reg = False, data = df)
sns.__version__
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-a3b9ebba1fee> in <module>
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       7
# ----> 8 df = pd.read_csv('/Users/artemshibaev/downloads/StudentsPerformance.csv')
#       9
#      10 ### LESSON 1
#
# ...

# %%
df_1 = pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')
some_cols = df_1.filter(like = '-')

# %%
df
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
#dota.groupby(['legs','localized_name']).describe().head(20)
#dota.groupby(['attack_type','primary_attr']).describe()
dota.loc[(dota.attack_type == 'Melee')].count()
# Out:
# Unnamed: 0        56
# attack_type       56
# id                56
# legs              56
# localized_name    56
# name              56
# primary_attr      56
# roles             56
# dtype: int64

# %%
dota.head(20)
# Out:
#     Unnamed: 0 attack_type  id  legs   localized_name  \
# 0            0       Melee   1     2        Anti-Mage
# 1            1       Melee   2     2              Axe
# 2            2      Ranged   3     4             Bane
# 3            3       Melee   4     2      Bloodseeker
# 4            4      Ranged   5     2   Crystal Maiden
# 5            5      Ranged   6     2      Drow Ranger
# 6            6       Melee   7     2      Earthshaker
# 7            7       Melee   8     2       Juggernaut
# 8            8      Ranged   9     2           Mirana
# 9            9      Ranged  10     0        Morphling
# 10          10      Ranged  11     0     Shadow Fiend
# 11          11       Melee  12     2   Phantom Lancer
# 12          12      Ranged  13     2             Puck
# 13          13       Melee  14     2            Pudge
# 14          14      Ranged  15     0            Razor
# 15          15       Melee  16     6        Sand King
# ...

# %%
lypa = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')
lypa.groupby(['Type', 'Executor']).aggregate({'Salary': 'mean'})
# Out:
#                    Salary
# Type Executor
# A    Loopa      58.000000
#      Pupa      160.833333
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Loopa     137.714286
#      Pupa      146.500000
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %%
lypa
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
concentrations.groupby('genus').aggregate({'alanin': 'describe'}).round(2).loc['Fucus']
# Out:
# alanin  count    3.00
#         mean     3.57
#         std      3.15
#         min      0.35
#         25%      2.03
#         50%      3.71
#         75%      5.18
#         max      6.64
# Name: Fucus, dtype: float64

# %%
algae = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
algae.groupby('group').aggregate({'citrate': 'var'}).round(3)
# Out:
#        citrate
# group
# brown    5.469
# green    3.950
# red        NaN

# %%
salary = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
#salary.income.plot() correct correletion between dates and salaries
#sns.lineplot(data = salary) correct correletion between dates and salaries
#sns.lineplot(x = salary.index, y = salary.income)

salary.plot(kind='line')

plt.plot(salary.index, salary.income)

sns.lineplot(data=salary)

salary['income'].plot()

sns.lineplot(x=salary.index, y=salary.income)

salary.income.plot()

salary.plot()

# %%
df123 = pd.read_csv("/Users/artemshibaev/downloads/dataset_209770_6.txt", sep=" ")
sns.lineplot(x = df123.x, y = df123.y)

# %%
genome = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col = 0)
g=sns.heatmap(data=genome, cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)
genome
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
dota2 = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
dota2['more_roles'] = dota2.roles.str.count(',')+1 #count the roles
dota2.more_roles.describe()
# Out:
# count    117.000000
# mean       4.000000
# std        1.090713
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        6.000000
# Name: more_roles, dtype: float64

# %%
flowers = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv')
flowers = flowers.\
            rename(columns = {'sepal length': 'sepal_length', 'sepal width': 'sepal_width',
                    'petal length': 'petal_length', 'petal width': 'petal_width'}).drop(['Unnamed: 0'], axis = 1)

# for column in flowers:
#     sns.kdeplot(flowers[column]) #showing many variables on one gpaph
ax = sns.violinplot(y="petal_length", data=flowers) #petal length in y Axis


#def get_redundant_pairs(df):
#     '''Get diagonal and lower triangular pairs of correlation matrix'''
#     pairs_to_drop = set()
#     cols = df.columns
#     for i in range(0, df.shape[1]):
#         for j in range(0, i+1):
#             pairs_to_drop.add((cols[i], cols[j]))
#     return pairs_to_drop

# def get_top_abs_correlations(df, n=5):
#     au_corr = df.corr().abs().unstack()
#     labels_to_drop = get_redundant_pairs(df)
#     au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
#     return au_corr[0:n]

# print("Top Absolute Correlations")
# print(get_top_abs_correlations(flowers, 3))


# ^ top rate of correlations for df

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')
# subset_1 = test.loc[(test['V1'] > 0) & (test['V3'] == 'A')] 
# subset_2 = test.loc[(test['V2'] != 0) | (test['V4'] >= 1)]
#my_stat.eval('V5 = V1 + V4').assign(V6 = np.log(my_stat.V2))
my_stat = my_stat.rename\
                                (columns = {'V1': 'session_value', 'V2': 'group', 'V3': 'time', 'V4': 'n_users'})
my_stat.session_value.fillna(0)
mea = my_stat.n_users.clip(lower = 0).median()
my_stat[my_stat['n_users'] < 0] = mea
my_stat.head(20)
# Out:
#    session_value  time group  n_users
# 0            0.0  12.0     B      9.0
# 1            3.5   3.5   3.5      3.5
# 2            1.0   8.0     A      1.0
# 3            2.0   9.0     B      3.0
# 4            2.0  10.0     B      9.0
# 5            3.0   8.0     A      8.0
# 6            NaN  11.0     B      5.0
# 7            0.0   9.0     A      4.0
# 8            3.5   3.5   3.5      3.5
# 9            3.5   3.5   3.5      3.5

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')
my_stat['session_value'].fillna(0, inplace = True)
mid = my_stat.n_users.clip(lower = 0).median() 
my_stat[my_stat['n_users'] < 0] = mid
mean_session_value_data = my_stat.rename(columns = {'session_value': 'mean_session_value'})
mean_session_value_data.groupby('group', as_index = False).agg({'mean_session_value': 'mean'})

#my_stat.groupby('group').agg({'session_value': 'mean'})
# Out:
#   group  mean_session_value
# 0   3.5            3.500000
# 1     A            1.333333
# 2     B            1.000000
